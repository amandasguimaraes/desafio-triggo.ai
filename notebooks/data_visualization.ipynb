# %%
# Importando bibliotecas
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Definindo constante de caminho
INTERMEDIATE_PATH = '../data/intermediate/'

# Verificando arquivos disponíveis
try:
    arquivos = [f for f in os.listdir(INTERMEDIATE_PATH) if f.endswith('.csv')]
    print(f"📁 {len(arquivos)} arquivos encontrados para análise.")
except FileNotFoundError:
    print(f"❌ Diretório {INTERMEDIATE_PATH} não encontrado. Verifique o caminho.")
    arquivos = []
# Out:
# 📁 9 arquivos encontrados para análise.

# %%
# Definindo função exploratória de dados
def explorar_dataframe(df, nome):
    print(f'\n{"="*50}')
    print(f'📘 Explorando: {nome.upper()}')
    print(f'{"="*50}')
    
    # Informações básicas
    print(f'\n🔍 Dimensões: {df.shape[0]} linhas x {df.shape[1]} colunas')
    
    # Amostra dos dados
    print('\n📋 Primeiras linhas:')
    display(df.head())
    
    # Informações sobre tipos de dados
    print('\nℹ️ Informações sobre tipos de dados:')
    df.info()
    
    # Resumo estatístico
    print('\n📊 Estatísticas descritivas:')
    display(df.describe(include='all').T)

# %%
# Carregando e explorando todas as tabelas
if arquivos:
    for arquivo in arquivos:
        nome_df = arquivo.replace('.csv', '')
        try:
            df = pd.read_csv(os.path.join(INTERMEDIATE_PATH, arquivo))
            explorar_dataframe(df, nome_df)
        except Exception as e:
            print(f"❌ Erro ao processar {arquivo}: {e}")
# Out:
# ...
# 📘 Explorando: CATEGORY_TRANSLATION
# ...
#
# 🔍 Dimensões: 71 linhas x 2 colunas
#
# 📋 Primeiras linhas:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# ℹ️ Informações sobre tipos de dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
#
# 📊 Estatísticas descritivas:
#                               count unique            top freq
# ...
